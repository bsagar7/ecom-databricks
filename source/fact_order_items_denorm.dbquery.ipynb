-- %%
CREATE OR REPLACE VIEW ecommerce.gold.fact_orders_denorm AS (
SELECT i.*,
c.year,
c.month_name,
c.day_name,
c.is_weekend,
c.quarter,
c.week,
p.sku, 
p.category_code,
p.category_name,
p.brand_code,
p.brand_name,
p.color,
p.size,
p.rating_count,
extract(HOUR FROM transaction_ts) as hour_of_day
FROM ecommerce.gold.fact_order_items_gld i JOIN ecommerce.gold.dim_date_gld c ON i.date_id = c.date_id
JOIN ecommerce.gold.dim_products_gld p ON i.product_id = p.product_id
);
